# %%
import time
import pandas as pd
# %matplotlib inline

from recycle_module_cy import *

from ema_workbench import ema_logging, perform_experiments, MultiprocessingEvaluator
ema_logging.log_to_stderr(ema_logging.INFO)
from ema_workbench.util import save_results, load_results
# Out:
# /home/yuvenious/anaconda3/envs/py36_32/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/yuvenious/anaconda3/envs/py36_32/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/yuvenious/anaconda3/envs/py36_32/lib/python3.6/site-packages/ema_workbench/em_framework/optimization.py:29: ImportWarning: platypus based optimization not available
#   warnings.warn("platypus based optimization not available", ImportWarning)

# %% [markdown]
# ### Experiment

# %%
experiment_model = set_model()

# %%
# n_scenarios = 1000
# n_policies = 50

# s = time.time()
# with MultiprocessingEvaluator(experiment_model) as evaluator:
#     results = evaluator.perform_experiments(n_scenarios, n_policies)
# # save_results(results, "results.tar.gz")
# e = time.time()
# print(round((e - s)/60, 2), "mins")

# %%
results = load_results("results.tar.gz")
experiments, outcomes = results_df(results)
# Out:
# [MainProcess/INFO] results loaded succesfully from /mnt/4E606B51606B3F39/GitRepository/agent-based-modeling/Plastic Recycling/results.tar.gz

# %%
uncertainties = experiments[list(experiment_model.uncertainties.keys())]
levers = experiments[list(experiment_model.levers.keys())]

# %%
for i in range(uncertainties.shape[1]):
    plot_cont(uncertainties, outcomes, i)

# %%
for i in range(levers.shape[1]):
    plot_cont(levers, outcomes, i)

# %%
uncertainties.to_csv("uncertainties.csv")
levers.to_csv("levers.csv")
outcomes.to_csv("outcomes.csv")
