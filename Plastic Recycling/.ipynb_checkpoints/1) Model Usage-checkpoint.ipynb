# %%
import numpy as np
import pandas as pd
from recycle_module_cy import Model, recycle_model
# %matplotlib inline
# Out:
# /home/yuvenious/anaconda3/envs/py36_32/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/yuvenious/anaconda3/envs/py36_32/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/yuvenious/anaconda3/envs/py36_32/lib/python3.6/site-packages/ema_workbench/em_framework/optimization.py:29: ImportWarning: platypus based optimization not available
#   warnings.warn("platypus based optimization not available", ImportWarning)

# %%
model = Model(mul_com = 2)
model.setup()

# %%
model.update()
model.log
# Out:
# [[0, 'model', 'initialized'],
#  [0, 'Municipality 0', 'population: 310 target 0.05 is created'],
#  [0, 'Municipality 0', 'Municipality 0 aggregates wastes, plastic, recycle:'],
#  [0, 'Municipality 0', '1037.5 206.33 62.07'],
#  [0, 'Municipality 0', 'Municipality 0 set budget 1037.5 292.11'],
#  [0, 'Municipality 1', 'population: 98 target 0.16 is created'],
#  [0, 'Municipality 1', 'Municipality 1 aggregates wastes, plastic, recycle:'],
#  [0, 'Municipality 1', '325.0 64.67 19.33'],
#  [0, 'Municipality 1', 'Municipality 1 set budget 325.0 92.26'],
#  [0, 'Company 0', 'capacity 300 tech 0.28 is created'],
#  [0, 'Company 1', 'capacity 869.391377012312 tech 0.23 is created'],
#  [0, 'Company 2', 'capacity 661.2789704582852 tech 0.25 is created'],
#  [0, 'Company 3', 'capacity 406.0280398720432 tech 0.08 is created'],
#  [0, 'Company 4', 'capacity 540.6104167382364 tech 0.19 is created'],
#  [0, 'Company 5', 'capacity 900 tech 0.11 is created'],
#  [1, 'Municipality 0', 'Municipality 0 update'],
#  [1, 'Municipality 0', 'Municipality 0 start bidding process'],
#  [1, 'Municipality 0', 'Municipality 0 create request 1037.5 0.05'],
#  [1, 'Municipality 1', 'Municipality 1 update'],
#  [1, 'Municipality 1', 'Municipality 1 start bidding process'],
#  [1, 'Municipality 1', 'Municipality 1 create request 325.0 0.16'],
#  [1, 'Municipality 1', 'Municipality 1 final request, initiate offer'],
#  [1, 'Company 1', 'Company 1 update'],
#  [1, 'Company 1', 'Company 1 makes an offer'],
#  [1, 'Company 1', 'Company 1 creates offers'],
#  [1, 'Company 5', 'Company 5 update'],
#  [1, 'Company 5', 'Company 5 makes an offer'],
#  [1, 'Company 5', 'Company 5 creates offers'],
#  [1, 'Company 4', 'Company 4 update'],
#  [1, 'Company 4', 'Company 4 makes an offer'],
#  [1, 'Company 4', 'Company 4 creates offers'],
#  [1, 'Company 3', 'Company 3 update'],
#  [1, 'Company 3', 'Company 3 makes an offer'],
#  [1, 'Company 3', 'Company 3 creates offers'],
#  [1, 'Company 0', 'Company 0 update'],
#  [1, 'Company 0', 'Company 0 makes an offer'],
#  [1, 'Company 0', 'Company 0 creates offers'],
#  [1, 'Company 2', 'Company 2 update'],
#  [1, 'Company 2', 'Company 2 makes an offer'],
#  [1, 'Company 2', 'Company 2 creates offers'],
#  [1, 'Company 2', 'Company 2 final offer, initiate selection'],
#  [1,
#   'Municipality 0',
#   "Municipality 0 (1037.5, 0.0519) select offer(s): [{'com': 5.0, 'capacity': 900.0, 'technology': 0.108, 'price': 97.0, 'fine': 0.0206, 'time': 1.0, 'period': 36.0, 'mun': 0.0}, {'com': 4.0, 'capacity': 540.6104167382364, 'technology': 0.186, 'price': 101.0, 'fine': 0.019, 'time': 1.0, 'period': 36.0, 'mun': 0.0}]"],
#  [1, 'Municipality 0', 'Municipality 0 gives contract'],
#  [1, 'Company 5', 'Company 5 receives contract from Municipality 0'],
#  [1, 'Company 4', 'Company 4 receives contract from Municipality 0'],
#  [1,
#   'Municipality 1',
#   "Municipality 1 (325.0, 0.1633) select offer(s): [{'com': 1.0, 'capacity': 869.391377012312, 'technology': 0.231, 'price': 201.0, 'fine': 0.0167, 'time': 1.0, 'period': 36.0, 'mun': 1.0}]"],
#  [1, 'Municipality 1', 'Municipality 1 gives contract'],
#  [1, 'Company 1', 'Company 1 receives contract from Municipality 1'],
#  [1, 'model', 'model close bid.'],
#  [1, 'Municipality 1', 'Municipality 1 update'],
#  [1, 'Municipality 1', 'Municipality 1 aggregates wastes, plastic, recycle:'],
#  [1, 'Municipality 1', '322.3 64.13 19.17'],
#  [1,
#   'Municipality 1',
#   'Municipality 1 check whether the target is met: False'],
#  [1, 'Municipality 1', 'Municipality 1 campaign → 0.2, 0.3'],
#  [1, 'Municipality 1', 'Municipality 1 waste: 322.3, expense: 322.3'],
#  [1, 'Municipality 0', 'Municipality 0 update'],
#  [1, 'Municipality 0', 'Municipality 0 aggregates wastes, plastic, recycle:'],
#  [1, 'Municipality 0', '1028.87 204.61 61.56'],
#  [1, 'Municipality 0', 'Municipality 0 check whether the target is met: True'],
#  [1, 'Municipality 0', 'Municipality 0 waste: 1028.87, expense: 1028.87'],
#  [1, 'Company 2', 'Company 2 update'],
#  [1, 'Company 2', 'Company 2 no client, no requests, thus: wait'],
#  [1, 'Company 2', 'Company 2 Invest on Technology, Reason: fail_win_contract'],
#  [1, 'Company 1', 'Company 1 update'],
#  [1, 'Company 1', 'Company 1 min_req vs. actual plastic volume: 174 | 64'],
#  [1, 'Company 1', 'Company 1 collect waste: 322.3 change: 322.3→0'],
#  [1, 'Company 1', 'Company 1 collect plastic: 64.14 change: 64.13→0'],
#  [1, 'Company 1', 'Company 1 claim fine to Municipality 1 3.36'],
#  [1, 'Company 0', 'Company 0 update'],
#  [1, 'Company 0', 'Company 0 no client, no requests, thus: wait'],
#  [1,
#   'Company 0',
#   'Company 0 Invest on Technology, Reason: low_cap(300, 681.25);fail_win_contract'],
#  [1, 'Company 5', 'Company 5 update'],
#  [1, 'Company 5', 'Company 5 min_req vs. actual plastic volume: 180 | 205'],
#  [1,
#   'Company 5',
#   'Company 5 collect waste: 900 change: 1028.87→128.8699999999999'],
#  [1,
#   'Company 5',
#   'Company 5 collect plastic: 179.1 change: 204.61→25.51000000000002'],
#  [1, 'Company 5', 'Company 5 no fine to Municipality 0'],
#  [1,
#   'Company 5',
#   'Company 5 Invest on Technology, Reason: low_tech(0.108, 0.19033333333333335)'],
#  [1, 'Company 3', 'Company 3 update'],
#  [1, 'Company 3', 'Company 3 no client, no requests, thus: wait'],
#  [1,
#   'Company 3',
#   'Company 3 Invest on Technology, Reason: low_tech(0.082, 0.19033333333333335);low_cap(406.0280398720432, 681.25);fail_win_contract'],
#  [1, 'Company 4', 'Company 4 update'],
#  [1, 'Company 4', 'Company 4 min_req vs. actual plastic volume: 108 | 26'],
#  [1,
#   'Company 4',
#   'Company 4 collect waste: 128.87 change: 128.8699999999999→0'],
#  [1,
#   'Company 4',
#   'Company 4 collect plastic: 25.65 change: 25.51000000000002→0'],
#  [1, 'Company 4', 'Company 4 claim fine to Municipality 0 1.92'],
#  [1,
#   'Company 4',
#   'Company 4 Invest on Technology, Reason: low_tech(0.186, 0.19033333333333335);low_cap(540.6104167382364, 681.25)']]

# %%
model.mun_list
# Out:
# [<recycle_module_cy.Model.Municipality at 0x7f2453fdc7b8>,
#  <recycle_module_cy.Model.Municipality at 0x7f245402d198>]

# %%
kwargs = {
    # model parameters
    'n_mun': 5,
    'mul_com': 4,

    'campaign_bud_prop': 0.1,
    'final_target': 0.5,
    
    # municipality parameters
    'target_mean': 0.1,
    'amb_mean': 0.3,
    'percep_range': 0.1,
    'know_range': 0.1,
    
    # company parameters
    'technology': 0.2,
    'tech_std': 0.1,
    'cap_mean': 600,
    'cap_std': 300,
}

# %%
model = Model(**kwargs)
model.setup()
for i in range(240):
    model.update()

# %%
model.plot_waste()
model.plot_target()

model.plot_municipality()
model.plot_company()

# %% [markdown]
# ### KPI

# %%
# Fraction of Municipalities which meet the target
target_met_frac = pd.Series([mun.target_met for mun in model.mun_list]).value_counts(True)
if True not in target_met_frac.index:
    target_met_frac = 0
else:
    target_met_frac = pd.Series([mun.target_met for mun in model.mun_list]).value_counts(True)[True]
target_met_frac
# Out:
# 0

# %%
# Fraction of Municipalities which has no budget left
no_budget_frac = pd.Series([mun.no_budget for mun in model.mun_list]).value_counts(True)
if True not in no_budget_frac.index:
    no_budget_frac = 0
else:
    no_budget_frac = pd.Series([mun.no_budget for mun in model.mun_list]).value_counts(True)[True]
no_budget_frac
# Out:
# 0.8

# %%
# avg time period that municipalities paid fine
arr_fine_period = np.array([len(mun.fine_history) for mun in model.mun_list])
avg_fine_period = arr_fine_period.mean()
avg_fine_period
# Out:
# 139.2

# %%
# Fine payment divided by populations (per Households)
np.array([mun.account_book[2].sum() / mun.n_pop for mun in model.mun_list]).mean()
# Out:
# 322.9174604631413

# %%
# 4. time for technology to converge
df = pd.DataFrame()
for com in model.com_list:
    df[com.unique_id] = com.tech_arr
std = df.apply(lambda x: x.std(), axis = 1)
std_conv = 0.03
if std.min() > 0.03:
    time_conv = 240
else:
    time_conv = std.where(std < std_conv).dropna().head(1).index[0]
time_conv
# Out:
# 238

# %%
# std of cumulative profits
np.array([com.profits[1].cumsum() for com in model.com_list]).mean(axis=1).std()
# Out:
# 81.53059686580438

# %% [markdown]
# ### KPI as a Function <code>recycle_model()</code>

# %%
for i in range(10):
    print(recycle_model())
# Out:
# (0, 0.3, 164.4, 229.3047420287673, 213, 386.5341012374892)
# (0, 0.3, 160.8, 169.76792152409527, 237, 366.2753997286131)
# (0, 0.2, 153.6, 242.1770725209345, 213, 340.7246837552339)
# (0, 0.2, 150.0, 237.21464201499094, 200, 294.4390248956413)
# (0, 0.3, 157.2, 136.88645585116396, 143, 334.74307205780684)
# (0, 0.2, 150.0, 176.01711938732527, 240, 376.3565178353251)
# (0, 0.2, 171.6, 96.04624163172502, 160, 522.8866281553169)
# (0, 0.1, 164.4, 151.8101550672772, 173, 405.76277079386296)
# (0, 0.4, 168.0, 172.30053898033458, 240, 382.29274436833066)
# (0, 0, 171.6, 157.5653815423872, 173, 399.67244301067905)
